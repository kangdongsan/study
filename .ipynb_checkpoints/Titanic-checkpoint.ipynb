# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:/Titanic/titanic/train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Survived : 0 = 사망, 1 = 생존
# Pclass : 1 = 1등석, 2 = 2등석, 3 = 3등석
# Sex : male = 남성, female = 여성
# Age : 나이
# SibSp : 타이타닉 호에 동승한 자매 / 배우자의 수
# Parch : 타이타닉 호에 동승한 부모 / 자식의 수
# Ticket : 티켓 번호
# Fare : 승객 요금
# Cabin : 방 호수
# Embarked : 탑승지, C = 셰르부르, Q = 퀸즈타운, S = 사우샘프턴

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

df=pd.DataFrame(data['Survived'].value_counts())
df=df.rename(index={0:"Death",1:"Survival"})
print(df)

df.plot.pie(y="Survived",autopct='%1.1f%%',ax=ax[0])
ax[0].set_title("Survived")
ax[0].set_ylabel("")

sns.countplot('Survived', data = data, ax=ax[1])
# ax[1].set_title("Survived")
plt.show()
# Out:
#           Survived
# Death          549
# Survival       342

# %%
data.groupby(["Sex","Survived"])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data1=data.drop("PassengerId", axis=1)
data1.groupby(["Sex","Survived"]).mean()
# Out:
#                    Pclass        Age     SibSp     Parch       Fare
# Sex    Survived
# female 0         2.851852  25.046875  1.209877  1.037037  23.024385
#        1         1.918455  28.847716  0.515021  0.515021  51.938573
# male   0         2.476496  31.618056  0.440171  0.207265  21.960993
#        1         2.018349  27.276022  0.385321  0.357798  40.821484

# %%
f,ax =plt.subplots(1,1,figsize=(18,8))
sns.countplot('Sex',data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue = "Survived", data=data, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap="PuBu")
# Out:
# <style  type="text/css" >
# #T_b8e486ca_45cf_11ec_891a_e0d55e489be0row0_col0,#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row1_col1,#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row1_col2{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row0_col1{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row0_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row1_col0{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row2_col0{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row2_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row2_col2{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row3_col0,#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row3_col1,#T_b8e486ca_45cf_11ec_891a_e0d55e489be0row3_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_b8e486ca_45cf_11ec_891a_e0d55e489be0row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(19,8))
print(data['Pclass'].value_counts())

data['Pclass'].value_counts(sort=True).plot.bar(ax=ax[0])
ax[0].set_title("Number of Passengers By Pclass")
ax[0].set_ylabel("Count")


sns.countplot("Pclass", hue="Survived", data =data, ax=ax[1])
ax[1].set_title("Pclass:Survived vs Dead")
plt.show()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
def highlight_max(data, color='yellow'): #코드 뜯어보기
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    
    
    else:  # from .apply(axis=None)
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
s = pd.crosstab([data.Sex,data.Survived], data.Pclass,margins=True)
s = s.style.highlight_max().format(None,na_rep="-")
s
# Out:
# <style  type="text/css" >
# #T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col0,#T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col1,#T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col2,#T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col3{
#             background-color:  yellow;
#         }</style><table id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_5fd6153c_45fe_11ec_b4d8_e0d55e489be0row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass',"Survived", hue="Sex", data=data)
plt.show()

# %%
print("Oldest Passenger was of :",data['Age'].max(), "Years")
print("Youngest Passenger was of :",data['Age'].min(), "Years")
print("Average Passenger was of :",data['Age'].mean(), "Years")
# Out:
# Oldest Passenger was of : 80.0 Years
# Youngest Passenger was of : 0.42 Years
# Average Passenger was of : 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(data=data, x="Pclass", y="Age", hue="Survived",split=True, inner="quart", linewidth=1,ax=ax[0])
sns.despine(left=True)
sns.violinplot(data=data, x="Sex", y="Age", hue="Survived",split=True, inner="quart", linewidth=1,ax=ax[1])
sns.despine(left=True)

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
    
print(data['Initial'])
#https://docs.python.org/3/howto/regex.html
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Initial, Length: 891, dtype: object

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
# #T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col0,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col1,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col3,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col4,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col5,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col7,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col8,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col12,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col15,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col16,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col2,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col6,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col9,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col10,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col11,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col13,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col2,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col6,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col9,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col10,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col11,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col13,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col14,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col0,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col1,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col3,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col4,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col5,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col7,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col8,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col12,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col15,#T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col16{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ba9cc677_4670_11ec_b215_e0d55e489be0" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba9cc677_4670_11ec_b215_e0d55e489be0level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col13" class="data row0 col13" >125</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col14" class="data row0 col14" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col15" class="data row0 col15" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row0_col16" class="data row0 col16" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_ba9cc677_4670_11ec_b215_e0d55e489be0level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col4" class="data row1 col4" >6</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col7" class="data row1 col7" >2</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col8" class="data row1 col8" >40</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col12" class="data row1 col12" >517</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col13" class="data row1 col13" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col15" class="data row1 col15" >6</td>
#                         <td id="T_ba9cc677_4670_11ec_b215_e0d55e489be0row1_col16" class="data row1 col16" >1</td>
#             </tr>
#     </tbody></table>

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
print(data['Initial'])
# Out:
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
#        ...
# 886    Other
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# Name: Initial, Length: 891, dtype: object

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
data.loc[(data.Age.isnull())&(data.Initial=="Mr"), "Age"]=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor="black",color="red")
ax[0].set_title('Survived= 0')

x1=list(range(0,85,5))
ax[0].set_xticks(x)
data[data["Survived"]==1].Age.plot
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')

x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived', col="Initial", data=data)
plt.show()

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived], margins=True).style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
# #T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col0,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col1{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col3{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col4,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col3{
#             background-color:  #e8f466;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col0,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row3_col0,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row3_col1,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row3_col2,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row3_col3,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row3_col4,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row4_col0,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row4_col2,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row4_col3,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row4_col4{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col1,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row6_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col3,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col4{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col0,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row5_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col2{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col4,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row7_col0{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row4_col1{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row5_col0{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row5_col2{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row5_col3{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row5_col4{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row6_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row6_col2{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row6_col3{
#             background-color:  #bede66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row6_col4{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row7_col1{
#             background-color:  #bdde66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row7_col2{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row7_col3,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row8_col1{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row7_col4{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row8_col0{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row8_col2{
#             background-color:  #81c066;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row8_col3{
#             background-color:  #b0d866;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row8_col4{
#             background-color:  #9acc66;
#             color:  #000000;
#         }#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row9_col0,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row9_col1,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row9_col2,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row9_col3,#T_b98cf712_467f_11ec_8cd5_e0d55e489be0row9_col4{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col1" class="data row0 col1" >42</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col2" class="data row0 col2" >25</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col3" class="data row0 col3" >17</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row0_col4" class="data row0 col4" >85</td>
#             </tr>
#             <tr>
#                                 <th id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0level1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col1" class="data row1 col1" >7</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col2" class="data row1 col2" >8</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row1_col4" class="data row1 col4" >17</td>
#             </tr>
#             <tr>
#                                 <th id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0level1_row2" class="row_heading level1 row2" >3</th>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col1" class="data row2 col1" >15</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col2" class="data row2 col2" >33</td>
#                         <td id="T_b98cf712_467f_11ec_8cd5_e0d55e489be0row2_col3" class="d

# %%
sns.factorplot('Embarked','Survived',data=data)
fig = plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')

sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')

sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')

sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %%
data['Embarked'].fillna('S',inplace=True)
print(data['Embarked'])

data.Embarked.isnull().any()
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object
# False

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_04f6861e_4684_11ec_94cc_e0d55e489be0row0_col0,#T_04f6861e_4684_11ec_94cc_e0d55e489be0row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row1_col0{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row1_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row2_col0,#T_04f6861e_4684_11ec_94cc_e0d55e489be0row4_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row3_col0,#T_04f6861e_4684_11ec_94cc_e0d55e489be0row3_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row4_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row5_col0,#T_04f6861e_4684_11ec_94cc_e0d55e489be0row5_col1,#T_04f6861e_4684_11ec_94cc_e0d55e489be0row6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_04f6861e_4684_11ec_94cc_e0d55e489be0row6_col0{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_04f6861e_4684_11ec_94cc_e0d55e489be0" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_04f6861e_4684_11ec_94cc_e0d55e489be0level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_04f6861e_4684_11ec_94cc_e0d55e489be0row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.pointplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_b94bacdc_4687_11ec_9648_e0d55e489be0row0_col0,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row0_col1,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row1_col0{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row1_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row1_col2{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row2_col0,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row4_col2{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row2_col1{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row2_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row3_col0,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row3_col2{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row3_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row4_col0,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row4_col1,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row5_col0,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row5_col1,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row5_col2,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row6_col0,#T_b94bacdc_4687_11ec_9648_e0d55e489be0row6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b94bacdc_4687_11ec_9648_e0d55e489be0row6_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_b94bacdc_4687_11ec_9648_e0d55e489be0" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_b94bacdc_4687_11ec_9648_e0d55e489be0level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_b94bacdc_4687_11ec_9648_e0d55e489be0row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.pointplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.show()

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')

sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')

sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix


fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()
